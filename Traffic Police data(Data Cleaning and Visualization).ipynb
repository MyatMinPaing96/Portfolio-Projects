# %%
import pandas as pd

data = pd.read_csv('/content/Police Dataset.csv')

data.head(2)
# Out:
#    stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0   1/2/2005      1:55           NaN             M          1985.0
# 1  1/18/2005      8:15           NaN             M          1965.0
#
#    driver_age driver_race violation_raw violation  search_conducted  \
# 0        20.0       White      Speeding  Speeding             False
# 1        40.0       White      Speeding  Speeding             False
#
#   search_type stop_outcome is_arrested stop_duration  drugs_related_stop
# 0         NaN     Citation       False      0-15 Min               False
# 1         NaN     Citation       False      0-15 Min               False

# %%
data.shape
# Out:
# (65535, 15)

# %%
data.isna().any()
# Out:
# stop_date             False
# stop_time             False
# country_name           True
# driver_gender          True
# driver_age_raw         True
# driver_age             True
# driver_race            True
# violation_raw          True
# violation              True
# search_conducted      False
# search_type            True
# stop_outcome           True
# is_arrested            True
# stop_duration          True
# drugs_related_stop    False
# dtype: bool

# %%
data[data['country_name'].isna() == 1]
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005      1:55           NaN             M          1985.0
# 1      1/18/2005      8:15           NaN             M          1965.0
# 2      1/23/2005     23:15           NaN             M          1972.0
# 3      2/20/2005     17:15           NaN             M          1986.0
# 4      3/14/2005     10:00           NaN             F          1984.0
# ...          ...       ...           ...           ...             ...
# 65530  12/6/2012     17:54           NaN             F          1987.0
# 65531  12/6/2012     22:22           NaN             M          1954.0
# 65532  12/6/2012     23:20           NaN             M          1985.0
# 65533  12/7/2012      0:23           NaN           NaN             NaN
# 65534  12/7/2012      0:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# ...

# %%
data.drop(columns='country_name',inplace = True)

# %%
data[data['driver_gender'].isna() == 1]
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 25      9/3/2005     16:02           NaN             NaN         NaN
# 29     9/26/2005      1:05           NaN             NaN         NaN
# 52     10/1/2005     13:09           NaN             NaN         NaN
# 110    10/3/2005     19:50           NaN             NaN         NaN
# 124    10/4/2005     11:43           NaN             NaN         NaN
# ...          ...       ...           ...             ...         ...
# 65427  12/2/2012      3:23           NaN             NaN         NaN
# 65488  12/5/2012      8:35           NaN             NaN         NaN
# 65493  12/5/2012     13:20           NaN             NaN         NaN
# 65502  12/5/2012     23:57           NaN             NaN         NaN
# 65533  12/7/2012      0:23           NaN             NaN         NaN
#
#       driver_race violation_raw violation  search_conducted search_type  \
# ...

# %%
data.dropna(subset = ['driver_gender'],inplace = True)

# %%
data.shape
# Out:
# (61474, 14)

# %%
data.isna().any()
# Out:
# stop_date             False
# stop_time             False
# driver_gender         False
# driver_age_raw         True
# driver_age             True
# driver_race           False
# violation_raw         False
# violation             False
# search_conducted      False
# search_type            True
# stop_outcome          False
# is_arrested           False
# stop_duration         False
# drugs_related_stop    False
# dtype: bool

# %%
data[data['driver_age_raw'].isna() == 1]
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 55443  1/11/2012      1:53             F             NaN         NaN
#
#       driver_race                   violation_raw  violation  \
# 55443    Hispanic  Equipment/Inspection Violation  Equipment
#
#        search_conducted search_type stop_outcome is_arrested stop_duration  \
# 55443             False         NaN      Warning       False      0-15 Min
#
#        drugs_related_stop
# 55443               False

# %%
data.head()
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
# 3  2/20/2005     17:15             M          1986.0        19.0       White
# 4  3/14/2005     10:00             F          1984.0        21.0       White
#
#       violation_raw violation  search_conducted search_type   stop_outcome  \
# 0          Speeding  Speeding             False         NaN       Citation
# 1          Speeding  Speeding             False         NaN       Citation
# 2          Speeding  Speeding             False         NaN       Citation
# 3  Call for Service     Other             False         NaN  Arrest Driver
# 4          Speeding  Speeding             False         NaN       Citation
#
#   is_arrested stop_duration  drugs_related_stop
# ...

# %%
data['driver_age_raw'] = data['driver_age_raw'].fillna(round(data['driver_age_raw'].mean(),2))

# %%
data.isna().any()
# Out:
# stop_date             False
# stop_time             False
# driver_gender         False
# driver_age_raw        False
# driver_age             True
# driver_race           False
# violation_raw         False
# violation             False
# search_conducted      False
# search_type            True
# stop_outcome          False
# is_arrested           False
# stop_duration         False
# drugs_related_stop    False
# dtype: bool

# %%
data[data['driver_age'].isna() == 1]
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 146     10/5/2005      8:50             M             0.0         NaN
# 281    10/10/2005     12:05             F             0.0         NaN
# 331    10/12/2005      7:50             M             0.0         NaN
# 414    10/17/2005      8:32             M          2005.0         NaN
# 455    10/18/2005     18:30             F             0.0         NaN
# ...           ...       ...           ...             ...         ...
# 57979   3/19/2012      0:24             M             0.0         NaN
# 58284   3/26/2012     12:50             M          2009.0         NaN
# 58497    4/1/2012      6:21             M             0.0         NaN
# 58498    4/1/2012      6:55             M             0.0         NaN
# 65360  11/29/2012      1:35             F             0.0         NaN
#
#       driver_race                   violation_raw         violation  \
# ...

# %%
data[data['driver_age_raw']== 0]['driver_age']
# Out:
# 146     NaN
# 281     NaN
# 331     NaN
# 455     NaN
# 748     NaN
#          ..
# 56155   NaN
# 57979   NaN
# 58497   NaN
# 58498   NaN
# 65360   NaN
# Name: driver_age, Length: 215, dtype: float64

# %%
data['driver_age'] =data.apply(lambda row: 0 if row['driver_age_raw'] == 0 else row['driver_age'], axis = 1)

# %%
data.isna().any()
# Out:
# stop_date             False
# stop_time             False
# driver_gender         False
# driver_age_raw        False
# driver_age             True
# driver_race           False
# violation_raw         False
# violation             False
# search_conducted      False
# search_type            True
# stop_outcome          False
# is_arrested           False
# stop_duration         False
# drugs_related_stop    False
# dtype: bool

# %%
data[data['driver_age'].isna() == 1]
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 414    10/17/2005      8:32             M         2005.00         NaN
# 3758     2/6/2006     13:20             M         2006.00         NaN
# 5200    3/29/2006     19:37             F         1997.00         NaN
# 6016    4/26/2006      9:15             F         2006.00         NaN
# 7397    6/12/2006     23:55             F         1887.00         NaN
# 8373    7/17/2006      8:20             F         2006.00         NaN
# 8656    7/27/2006     19:08             M         2006.00         NaN
# 9059     8/9/2006      9:10             M         2006.00         NaN
# 9359    8/22/2006      6:30             F         2006.00         NaN
# 10023   9/12/2006     17:40             M         2006.00         NaN
# 10357   9/24/2006     17:30             M         2004.00         NaN
# 10827  10/11/2006     10:55             M         2002.00         NaN
# ...

# %%
data.loc[55443]
# Out:
# stop_date                                  1/11/2012
# stop_time                                       1:53
# driver_gender                                      F
# driver_age_raw                               1967.85
# driver_age                                       NaN
# driver_race                                 Hispanic
# violation_raw         Equipment/Inspection Violation
# violation                                  Equipment
# search_conducted                               False
# search_type                                      NaN
# stop_outcome                                 Warning
# is_arrested                                    False
# stop_duration                               0-15 Min
# drugs_related_stop                             False
# Name: 55443, dtype: object

# %%
data.describe()
# Out:
#        driver_age_raw    driver_age
# count    61474.000000  61437.000000
# mean      1967.854115     34.030096
# std        120.535455     12.897258
# min          0.000000      0.000000
# 25%       1965.000000     23.000000
# 50%       1978.000000     31.000000
# 75%       1985.000000     43.000000
# max       8801.000000     88.000000

# %%
data['driver_age_raw'].dtype
# Out:
# dtype('float64')

# %%
data['driver_age_raw'].astype('int')
# Out:
# 0        1985
# 1        1965
# 2        1972
# 3        1986
# 4        1984
#          ...
# 65529    1994
# 65530    1987
# 65531    1954
# 65532    1985
# 65534    1985
# Name: driver_age_raw, Length: 61474, dtype: int64

# %%
data['driver_age'] = data.apply(lambda row: 2005 - row['driver_age_raw'] if pd.isna(row['driver_age']) else row['driver_age'],axis = 1)

# %%
data.isna().any()
# Out:
# stop_date             False
# stop_time             False
# driver_gender         False
# driver_age_raw        False
# driver_age            False
# driver_race           False
# violation_raw         False
# violation             False
# search_conducted      False
# search_type            True
# stop_outcome          False
# is_arrested           False
# stop_duration         False
# drugs_related_stop    False
# dtype: bool

# %%
data.shape
# Out:
# (61474, 14)

# %%
data[data['search_type'].isna() == 0]
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65529  12/6/2012     16:00             M          1994.0        18.0
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %%
data.drop(columns = 'search_type',inplace = True)

# %%
data.isna().any()
# Out:
# stop_date             False
# stop_time             False
# driver_gender         False
# driver_age_raw        False
# driver_age            False
# driver_race           False
# violation_raw         False
# violation             False
# search_conducted      False
# stop_outcome          False
# is_arrested           False
# stop_duration         False
# drugs_related_stop    False
# dtype: bool

# %%
data[data.duplicated(keep=False)]
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 15      7/19/2005      0:30             M          1982.0        23.0
# 16      7/19/2005      0:30             M          1982.0        23.0
# 103     10/3/2005     13:26             M          1975.0        30.0
# 104     10/3/2005     13:26             M          1975.0        30.0
# 116     10/4/2005      0:36             M          1961.0        44.0
# ...           ...       ...           ...             ...         ...
# 63849   9/21/2012     10:14             M          1979.0        33.0
# 64322  10/11/2012      6:10             M          1952.0        60.0
# 64323  10/11/2012      6:10             M          1952.0        60.0
# 65406  11/30/2012     22:16             M          1990.0        22.0
# 65407  11/30/2012     22:16             M          1990.0        22.0
#
#       driver_race                   violation_raw            violation  \
# ...

# %%
data.drop_duplicates(inplace = True)

# %%
data.shape
# Out:
# (61291, 13)

# %%
data.head(10)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
# 3  2/20/2005     17:15             M          1986.0        19.0       White
# 4  3/14/2005     10:00             F          1984.0        21.0       White
# 5  3/23/2005      9:45             M          1982.0        23.0       Black
# 6   4/1/2005     17:30             M          1969.0        36.0       White
# 7   6/6/2005     13:20             F          1986.0        19.0       White
# 8  7/13/2005     10:15             M          1970.0        35.0       Black
# 9  7/13/2005     15:45             M          1970.0        35.0       White
#
#                     violation_raw  violation  search_conducted   stop_outcome  \
# ...

# %% [markdown]
# **Data Cleaning Process is finished**

# %%
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import Figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (8,6)

# %% [markdown]
# Q1. For Speeding, were Men or Women stopped more often?

# %%
data.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted stop_outcome is_arrested  \
# 0      Speeding  Speeding             False     Citation       False
# 1      Speeding  Speeding             False     Citation       False
#
#   stop_duration  drugs_related_stop
# 0      0-15 Min               False
# 1      0-15 Min               False

# %%
data['violation'].value_counts()
# Out:
# violation
# Speeding               37102
# Moving violation       11894
# Equipment               6498
# Other                   3569
# Registration/plates     2225
# Seat belt                  3
# Name: count, dtype: int64

# %%
gender_counts = data[data['violation']=='Speeding'].driver_gender.value_counts()

gender_counts
# Out:
# driver_gender
# M    25441
# F    11661
# Name: count, dtype: int64

# %%
gender_counts.plot(kind = 'bar',color = ['blue','pink'])
plt.title('Number of Speeding Violations by Gender')
plt.xlabel('Genders')
plt.ylabel('Counts')
plt.show()

# %% [markdown]
# Q3.Does gender affect who gets searched during a stop?

# %%
data.head()
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
# 3  2/20/2005     17:15             M          1986.0        19.0       White
# 4  3/14/2005     10:00             F          1984.0        21.0       White
#
#       violation_raw violation  search_conducted search_type   stop_outcome  \
# 0          Speeding  Speeding             False           -       Citation
# 1          Speeding  Speeding             False           -       Citation
# 2          Speeding  Speeding             False           -       Citation
# 3  Call for Service     Other             False           -  Arrest Driver
# 4          Speeding  Speeding             False           -       Citation
#
#   is_arrested stop_duration  drugs_related_stop
# ...

# %%
who_search = data.groupby('driver_gender').search_conducted.sum()
who_search
# Out:
# driver_gender
# F     365
# M    2105
# Name: search_conducted, dtype: int64

# %%
who_search.plot(kind = 'barh', color = ['Orange','Teal'])
plt.title('Who gets searched during a stop')
plt.xlabel('Counts')
plt.ylabel('Gender')
plt.show()

# %%
search_counts = data.search_conducted.value_counts()
search_counts
# Out:
# search_conducted
# False    58821
# True      2470
# Name: count, dtype: int64

# %%
search_counts.plot(kind = 'bar', color = ['red','blue'])
plt.title('Search conducted by gender')
plt.xlabel('Gender')
plt.ylabel('Counts')
plt.show()

# %% [markdown]
# Q3. What is the mean stop_duration?

# %%
data['stop_duration'] = data['stop_duration'].map({'0-15 Min': 7.5, '16-30 Min': 24,'30+ Min': 45 })

# %%
data['stop_duration'].dtype
# Out:
# dtype('float64')

# %%
data['stop_duration'] = data['stop_duration'].astype('str')

# %%
data['stop_duration'].dtype
# Out:
# dtype('O')

# %%
data['stop_duration'] = data['stop_duration'].astype('float')

# %%
data['stop_duration'].mean()
# Out:
# 12.175305922662751

# %% [markdown]
# Q4. Compare the age distributions for each violation

# %%
data.groupby('violation').driver_age.value_counts()
# Out:
# violation  driver_age
# Equipment  23.0          385
#            21.0          372
#            22.0          370
#            20.0          346
#            24.0          329
#                         ...
# Speeding   5.0             1
#            7.0             1
#            15.0            1
#            83.0            1
#            118.0           1
# Name: count, Length: 357, dtype: int64

# %%
data[data['driver_age'] >70]
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 725    10/28/2005      9:40             M          1924.0        81.0
# 774    10/29/2005     12:25             M          1929.0        76.0
# 973     11/4/2005     11:50             M          1930.0        75.0
# 1043    11/5/2005     22:30             M          1931.0        74.0
# 1191   11/10/2005     18:58             M          1923.0        82.0
# ...           ...       ...           ...             ...         ...
# 64288   10/9/2012      3:32             M          1938.0        74.0
# 64378  10/13/2012     11:56             M          1937.0        75.0
# 64515  10/19/2012     16:28             M          1939.0        73.0
# 64873   11/7/2012     10:17             M          1941.0        71.0
# 65464   12/4/2012      7:41             F          1939.0        73.0
#
#       driver_race            violation_raw         violation  \
# 725         White                 Speeding          Speeding
# ...
